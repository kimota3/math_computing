# %%
import numpy as np
import matplotlib.pyplot as plt

# 목적함수 f(x) = x1^2 + x2^2
def f1(x1, x2):
    return x1**2 + x2** 2

x1 = np.linspace(-5, 5, 100)
x2 = np.linspace(-3, 3, 100)
X1, X2 = np.meshgrid(x1, x2)
Y = f1(X1, X2)

# 등식 제한조건 방정식 g(x) = x1 + x2 - 1 = 0
x2_g = 1 - x1


CC=plt.contour(X1, X2, Y, levels=[0.5, 2, 8, 32])
plt.plot(x1, x2_g, 'g-')


plt.clabel(CC,inline=2,fontsize = 9)

plt.colorbar


plt.plot([0], [0], 'rP')
plt.plot([0.5], [0.5], 'ro', ms=10)

plt.xlim(-5, 5)
plt.ylim(-3, 3)
plt.xticks(np.linspace(-4, 4, 9))
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.title("test")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 목적함수 f(x) = x1^2 + x2^2
def f1(x1, x2):
    return x1 ** 2 + x2
x1 = np.linspace(-3, 3, 100)
x2 = np.linspace(-3, 3, 100)
X1, X2 = np.meshgrid(x1, x2)
Y = f1(X1, X2)

# 등식 제한조건 방정식 g(x) = x1 + x2 - 1 = 0
x2_g = np.sqrt(+1 - x1**2)
x3_g = -np.sqrt(+1 - x1**2)
#CC = plt.contour(X_2,Y_2,Z_2,levels=np.arange(-1,1,0.2))

plt.clabel(CC,inline=2,fontsize = 9)

plt.colorbar



CC=plt.contour(X1, X2, Y, colors="gray", levels=[-1,0.5, 5/4,2, 8])
plt.clabel(CC,inline=2,fontsize = 9)

plt.colorbar
plt.plot(x1, x2_g, 'g-')
plt.plot(x1, x3_g, 'g-')

#plt.plot([], [], 'rP')
#plt.plot([], [], 'ro', ms=10)

#plt.xlim(-3, 1)
#plt.ylim(-1, 1)
#plt.xticks(np.linspace(-3, 3, 9))
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
#plt.title(" ")
plt.show()
# Out:
# <ipython-input-39-6f9195c43b70>:13: RuntimeWarning: invalid value encountered in sqrt
#   x2_g = np.sqrt(+1 - x1**2)
# <ipython-input-39-6f9195c43b70>:14: RuntimeWarning: invalid value encountered in sqrt
#   x3_g = -np.sqrt(+1 - x1**2)

# %%
from sympy import * # sympy 모듈에서 모두(*) 불러옴
x,y = symbols('x y')
init_printing() # 수식을 LaTex 스타일로 표시한다.

ff = x**2 + y**2 + y*x**2 + 4

deriv_x= Derivative(ff,x)

Eq(deriv_x,deriv_x.doit())
# Out:
# ∂ ⎛ 2      2    2    ⎞
# ──⎝x ⋅y + x  + y  + 4⎠ = 2⋅x⋅y + 2⋅x
# ∂x

# %%
import sympy as sp
import numpy as np 
import matplotlib.pyplot as plt

x, y = sp.symbols('x y')
k = x**2 + y**2 + x*y - sp.sin(x)*5

k_by_x = sp.diff(k, x)
k_by_y = sp.diff(k, y)

# make meshgrid with xs, ys 
n=50
x_3 = np.linspace(-10, 10, n)
y_3 = np.linspace(-10, 10, n)
X_3, Y_3= np.meshgrid(x_3, y_3)

# make zs 
#zs = [float(k.subs(x, xv).subs(y, yv)) for xv, yv in zip(X_3.ravel(), Y_3.ravel())]
#zs = np.array(zs).reshape(sample_size, sample_size)
Z_3 = [float(k.subs(x,xv).subs(y,yv)) for xv, yv in zip(X_3.ravel(), Y_3.ravel())]
Z_3=np.array(Z_3).reshape(n,n)
#print(Z_3)

fig=plt.figure(figsize=(16, 8))

#fig=plt.figure()
#ax = fig.add_subplot(121, projection='3d')
#ax.plot_surface(X_3, Y_3, Z_3, cmap='viridis')
#ax.view_init(10,70) 
#plt.show()

#ax=fig.add_subplot(121)
plt.contour(X_3, Y_3, Z_3, 50, levels = np.logspace(-1.0, 2.0, 20), cmap=plt.cm.rainbow)

# gradient

X_4, Y_4 = np.meshgrid( np.linspace(-10, 10, 10), np.linspace(-10, 10, 10) )

XG = [float(k_by_x.subs(x, xx).subs(y, yy)) for xx, yy in zip(X_4.ravel(), Y_4.ravel())]

YG = [float(k_by_y.subs(x, xx).subs(y, yy)) for xx, yy in zip(X_4.ravel(), Y_4.ravel())]

plt.quiver(X_4, Y_4, XG, YG, width=0.005, scale=500, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 목적함수 f(x) = x1^2 + x2^2
def f1(x1, x2):
    return x1**2 + x2** 2

x1 = np.linspace(-3.5, 3.5, 100)
x2 = np.linspace(-3.5, 3.5, 100)
X1, X2 = np.meshgrid(x1, x2)
Y = f1(X1, X2)

# 등식 제한조건 방정식 g(x) = x1 + x2 - 1 = 0
x2_g = 1 - x1

fig=plt.figure(figsize=(6, 6))
CC=plt.contour(X1, X2, Y, colors="gray",levels=[0.5, 2, 6])
plt.plot(x1, x2_g, 'g-')


plt.clabel(CC,inline=2,fontsize = 9)

#plt.colorbar


#plt.plot([0], [0], 'bo')
plt.plot([0.5], [0.5], 'bo', ms=10)

#plt.xlim(-5, 5)
#plt.ylim(-5, 5)
#plt.xticks(np.linspace(-3, 4, 9))
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
#plt.title("test")
plt.show()
